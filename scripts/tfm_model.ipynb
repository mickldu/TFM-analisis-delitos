# %% [markdown]
# 1: Setup y carga de datos

# %%
# --- Setup Inicial y carga de datos ---

# %pip install pandas

from IPython.display import display
import pandas as pd

# Cargar datos (ajusta el nombre del archivo si es necesario)
df = pd.read_csv("data_tfm.csv", encoding='utf-8')


# Verifica estructura y primeras filas
display(df.head())
print(f"Shape (filas, columnas): {df.shape}")
print("\nColumnas y tipos:")
print(df.dtypes)
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 11.3/11.3 MB 5.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.9/12.9 MB 6.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 509.2/509.2 kB 6.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 9
#       6 import pandas as pd
#       8 # Cargar datos (ajusta el nombre del archivo si es necesario)
# ----> 9 df = pd.read_csv("data_tfm.csv", encoding='utf-8')
#      12 # Verifica estructura y primeras filas
#      13 display(df.head())
#
# ...
